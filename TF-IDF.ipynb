# %%
import pandas as pd

# better display of review text in dataframes
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# # Load Dataset

# %%
import pickle

PICKLE_PATH = "allocine_dataset/data/allocine_dataset.pickle"

with open(PICKLE_PATH, 'rb') as reader:
    data = pickle.load(reader)
    
train_df = data["train_set"]
dev_df = data["dev_set"]
test_df = data["test_set"]
    
print("LEN TRAIN: "+ str(len(train_df)))
print("LEN DEV: "+ str(len(dev_df)))
print("LEN TEST: "+ str(len(test_df)))
# Out:
# LEN TRAIN: 11996
# LEN DEV: 4003
# LEN TEST: 4001

# %%
train_df.head()
# Out:
#                                                               film-url  \
# 0   http://www.allocine.fr/film/fichefilm-265567/critiques/spectateurs
# 29  http://www.allocine.fr/film/fichefilm-265567/critiques/spectateurs
# 40  http://www.allocine.fr/film/fichefilm-265262/critiques/spectateurs
# 60  http://www.allocine.fr/film/fichefilm-224808/critiques/spectateurs
# 62  http://www.allocine.fr/film/fichefilm-224808/critiques/spectateurs
#
# ...

# %% [markdown]
# # Preprocessing

# %%
# !python -m spacy download fr_core_news_md
# Out:
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('fr_core_news_md')

# %%
import spacy

nlp = spacy.load("fr_core_news_md", disable=["parser", "entity"])

# %%
review_text = train_df.iloc[0]['review']
#print(review_text)

doc = nlp(review_text)
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.dep_)
# Out:
# Franchement franchement ADV
# un un DET
# film film NOUN
# invraisemblable invraisemblable ADJ
# , , PUNCT
# une un DET
# histoire histoire NOUN
# incongru incongru VERB
# à à ADP
# la le DET
# quelle quell ADJ
# je je PRON
# n' n' ADV
# ai avoir AUX
# pas pas ADV
# réussi réussir VERB
# à à ADP
# adhérer adhérer VERB
# . . PUNCT
# Un un DET
# homme homme NOUN
# mourrant mourrant ADJ
# , , PUNCT
# au au DET
# sol sol NOUN
# qui qui PRON
# arrive arrive VERB
# en en ADP
# poignarder poignarder VERB
# l' le DET
# un un PRON
# des un DET
# personnages personnage NOUN
# principaux principal ADJ
# , , PUNCT
# des un DET
# courses course NOUN
# poursuites poursuite ADJ
# ou ou CCONJ
# les le DET
# soldats soldat NOUN
# allemands allemand ADJ
# tirs tir ADJ
# sans sans ADP
# même même ADV
# mettre mettre VERB
# en en ADP
# joue joue NOUN
# , , PUNCT
# on on PRON
# dirait dire VERB
# que que SCONJ
# se se PRON
# sont être AUX
# des un DET
# enfants enfant NOUN
# de de ADP
# 10ans 10ans NUM
# ...

# %%
import string

# Create our list of punctuation marks
punctuations = string.punctuation
stop_words = spacy.lang.fr.stop_words.STOP_WORDS

# Creating our tokenizer function
def spacy_tokenizer(sentence):
    # Creating our token object, which is used to create documents with linguistic annotations.
    tokens = nlp(sentence)

    # Lemmatizing each token and converting each token into lowercase
    tokens = [tok.lemma_.lower().strip() for tok in tokens]
    
    tokens = [tok for tok in tokens if tok not in punctuations]

    # Removing stop words
    tokens = [tok for tok in tokens if tok not in stop_words]

    # return preprocessed list of tokens
    return tokens

# %%
spacy_tokenizer(review_text)
# Out:
# ['franchement',
#  'film',
#  'invraisemblable',
#  'histoire',
#  'incongru',
#  'quell',
#  'réussir',
#  'adhérer',
#  'homme',
#  'mourrant',
#  'sol',
#  'arrive',
#  'poignarder',
#  'personnage',
#  'principal',
#  'course',
#  'poursuite',
#  'soldat',
#  'allemand',
#  'tir',
#  'mettre',
#  'joue',
#  'enfant',
#  '10ans',
#  'amuser',
#  'jouer',
#  '2',
#  'acteur',
#  'principal',
#  'empoter',
#  'mouvement',
#  'magnifique',
#  'sprint',
#  'final',
#  'agonie',
#  'déjà',
#  'bout',
#  'temps',
#  'saute',
#  'torrent',
#  'pleine',
#  'tombe',
#  'cascade',
#  'bon',
#  'aller',
#  'finir',
#  'faire',
#  'erreur',
#  'aller',
#  'voir',
#  'vf',
#  'traduction',
#  'horrible',
#  'invraisemblance',
#  'poto',
#  'passer']
